# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv('Salary_Data.csv')
x = dataset.iloc[:, :-1].values
y = dataset.iloc[:, -1].values
print(x)
print(y)
# Out:
# [[ 1.1]
#  [ 1.3]
#  [ 1.5]
#  [ 2. ]
#  [ 2.2]
#  [ 2.9]
#  [ 3. ]
#  [ 3.2]
#  [ 3.2]
#  [ 3.7]
#  [ 3.9]
#  [ 4. ]
#  [ 4. ]
#  [ 4.1]
#  [ 4.5]
#  [ 4.9]
#  [ 5.1]
#  [ 5.3]
#  [ 5.9]
#  [ 6. ]
#  [ 6.8]
#  [ 7.1]
#  [ 7.9]
#  [ 8.2]
#  [ 8.7]
#  [ 9. ]
#  [ 9.5]
#  [ 9.6]
#  [10.3]
#  [10.5]]
# [ 39343.  46205.  37731.  43525.  39891.  56642.  60150.  54445.  64445.
#   57189.  63218.  55794.  56957.  57081.  61111.  67938.  66029.  83088.
#   81363.  93940.  91738.  98273. 101302. 113812. 109431. 105582. 116969.
#  112635. 122391. 121872.]

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=0)

# %%
from sklearn.linear_model import LinearRegression
regression = LinearRegression()
regression.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = regression.predict(x_test)
print(y_pred)
predict_sal = np.array([[12]])
print(regression.predict(predict_sal))
# Out:
# [ 40748.96184072 122699.62295594  64961.65717022  63099.14214487
#  115249.56285456 107799.50275317]
# [138531.00067138]

# %%
plt.scatter(x_train, y_train, color='red')
plt.plot(x_train, regression.predict(x_train), color='blue')
plt.title("Salary Data Graph")
plt.xlabel("Salary")
plt.ylabel("Data")
# Out:
# Text(0, 0.5, 'Data')

# %%
plt.scatter(x_test, y_test, color='red')
plt.plot(x_test, regression.predict(x_test), color='blue')
plt.title("Salary Data Graph")
plt.xlabel("Salary")
plt.ylabel("Data")
# Out:
# Text(0, 0.5, 'Data')

# %%
b0 = regression.intercept_
b1 = regression.coef_[0]
print("Intercept (b0):", b0)
print("Slope (b1):", b1)
print(f"Regression Equation: y = {b0:.2f} + {b1:.2f}x")
# Out:
# Intercept (b0): 26780.09915062818
# Slope (b1): 9312.575126729189
# Regression Equation: y = 26780.10 + 9312.58x
